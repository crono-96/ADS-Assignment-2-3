# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df1= df[['Attrition' , 'DistanceFromHome' , 'JobRole' , 'Education' , 'MonthlyIncome']]

# %%
df1
# Out:
#      Attrition  DistanceFromHome                    JobRole  Education  \
# 0          Yes                 1            Sales Executive          2
# 1           No                 8         Research Scientist          1
# 2          Yes                 2      Laboratory Technician          2
# 3           No                 3         Research Scientist          4
# 4           No                 2      Laboratory Technician          1
# ...        ...               ...                        ...        ...
# 1465        No                23      Laboratory Technician          2
# 1466        No                 6  Healthcare Representative          1
# 1467        No                 4     Manufacturing Director          3
# 1468        No                 2            Sales Executive          3
# 1469        No                 8      Laboratory Technician          3
#
#       MonthlyIncome
# 0              5993
# 1              5130
# 2              2090
# 3              2909
# ...

# %%
plt.figure(figsize = (20, 10))
sns.barplot (x = "JobRole" , y= "DistanceFromHome" , data = df1 , hue = "Attrition")

# %%
df2 = df1[['DistanceFromHome', 'JobRole' , 'Attrition']][df1['Attrition'] == "No"]
df3 = df1[['DistanceFromHome', 'JobRole' , 'Attrition']][df1['Attrition'] == "Yes"]

# %%
df2 = df2.rename (columns = {'Attrition' : 'Attrition_No'})
df3 = df3.rename (columns = {'Attrition' : 'Attrition_Yes'})

# %%
df2
# Out:
#       DistanceFromHome                    JobRole Attrition_No
# 1                    8         Research Scientist           No
# 3                    3         Research Scientist           No
# 4                    2      Laboratory Technician           No
# 5                    2      Laboratory Technician           No
# 6                    3      Laboratory Technician           No
# ...                ...                        ...          ...
# 1465                23      Laboratory Technician           No
# 1466                 6  Healthcare Representative           No
# 1467                 4     Manufacturing Director           No
# 1468                 2            Sales Executive           No
# 1469                 8      Laboratory Technician           No
#
# [1233 rows x 3 columns]

# %%
df3
# Out:
#       DistanceFromHome                JobRole Attrition_Yes
# 0                    1        Sales Executive           Yes
# 2                    2  Laboratory Technician           Yes
# 14                  24  Laboratory Technician           Yes
# 21                   9   Sales Representative           Yes
# 24                   6     Research Scientist           Yes
# ...                ...                    ...           ...
# 1438                 9   Sales Representative           Yes
# 1442                 1     Research Scientist           Yes
# 1444                 7  Laboratory Technician           Yes
# 1452                 1        Sales Executive           Yes
# 1461                28        Sales Executive           Yes
#
# [237 rows x 3 columns]

# %%
df2.groupby(['DistanceFromHome', 'JobRole']).count()
# Out:
#                                             Attrition_No
# DistanceFromHome JobRole
# 1                Healthcare Representative            23
#                  Human Resources                       8
#                  Laboratory Technician                27
#                  Manager                              13
#                  Manufacturing Director               23
# ...                                                  ...
# 29               Manager                               3
#                  Manufacturing Director                4
#                  Research Scientist                    3
#                  Sales Executive                       4
#                  Sales Representative                  1
#
# [217 rows x 1 columns]

# %%
df3.groupby(['DistanceFromHome', 'JobRole']).count()
# Out:
#                                             Attrition_Yes
# DistanceFromHome JobRole
# 1                Human Resources                        1
#                  Laboratory Technician                  4
#                  Manufacturing Director                 1
#                  Research Scientist                     7
#                  Sales Executive                        6
# ...                                                   ...
# 29               Healthcare Representative              1
#                  Laboratory Technician                  1
#                  Manager                                1
#                  Research Scientist                     1
#                  Sales Executive                        1
#
# [112 rows x 1 columns]

# %%
df4= df1[['Education', 'MonthlyIncome' , 'Attrition']]

# %%
df4
# Out:
#       Education  MonthlyIncome Attrition
# 0             2           5993       Yes
# 1             1           5130        No
# 2             2           2090       Yes
# 3             4           2909        No
# 4             1           3468        No
# ...         ...            ...       ...
# 1465          2           2571        No
# 1466          1           9991        No
# 1467          3           6142        No
# 1468          3           5390        No
# 1469          3           4404        No
#
# [1470 rows x 3 columns]

# %%
df5 = df4.groupby(['Education', 'Attrition']).mean()

# %%
df5
# Out:
#                      MonthlyIncome
# Education Attrition
# 1         No           5926.129496
#           Yes          4360.161290
# 2         No           6586.058824
#           Yes          4282.545455
# 3         No           6882.919662
#           Yes          4770.242424
# 4         No           7087.814706
#           Yes          5335.155172
# 5         No           8559.906977
#           Yes          5850.200000

# %%
plt.figure (figsize =(20,10))
sns.barplot (x= "Education" , y= "MonthlyIncome", data = df1 , hue ="Attrition")
